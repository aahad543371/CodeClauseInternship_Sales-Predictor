# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
file_path = r"C:\Users\Ayesha Siddikha\Documents\SALES.xlsx"
df = pd.read_excel(file_path)
df.head()
# Out:
#    INDEX     TV  RADIO  NEWSPAPER  SALES
# 0      0  230.1   37.8       69.2   22.1
# 1      1   44.5   39.3       45.1   10.4
# 2      2   17.2   45.9       69.3   12.0
# 3      3  151.2   41.3       58.5   16.5
# 4      4  180.8   10.8       58.4   17.5

# %%
df.shape
# Out:
# (5, 5)

# %%
df.describe()
# Out:
#           INDEX          TV      RADIO  NEWSPAPER      SALES
# count  5.000000    5.000000   5.000000   5.000000   5.000000
# mean   2.000000  124.760000  35.020000  60.100000  15.700000
# std    1.581139   90.756394  13.878653   9.973715   4.653493
# min    0.000000   17.200000  10.800000  45.100000  10.400000
# 25%    1.000000   44.500000  37.800000  58.400000  12.000000
# 50%    2.000000  151.200000  39.300000  58.500000  16.500000
# 75%    3.000000  180.800000  41.300000  69.200000  17.500000
# max    4.000000  230.100000  45.900000  69.300000  22.100000

# %%
warnings.filterwarnings("ignore", message="The figure layout has changed to tight")
sns.pairplot(df, x_vars=['TV', 'RADIO', 'NEWSPAPER'], y_vars='SALES', kind='scatter')
plt.show()

# %%
df['TV'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['RADIO'].plot.hist(bins=10, color="blue", xlabel="RADIO")
# Out:
# <Axes: xlabel='RADIO', ylabel='Frequency'>

# %%
df['NEWSPAPER'].plot.hist(bins=10, color="purple", xlabel="NEWSPAPER")
# Out:
# <Axes: xlabel='NEWSPAPER', ylabel='Frequency'>

# %%
sns.heatmap(df.corr(),annot = True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[['TV']], df[['SALES']], test_size = 0.3,random_state=0)

# %%
print(x_train)
# Out:
#       TV
# 1   44.5
# 3  151.2
# 4  180.8

# %%
print(y_train)
# Out:
#    SALES
# 1   10.4
# 3   16.5
# 4   17.5

# %%
print(x_test)
# Out:
#       TV
# 2   17.2
# 0  230.1

# %%
print(y_test)
# Out:
#    SALES
# 2   12.0
# 0   22.1

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [raw]
# res= model.predict(x_test)
# print(res)

# %%
model.coef_
# Out:
# array([[0.05344576]])

# %%
model.intercept_
# Out:
# array([8.0925567])

# %%
0.05344576* 69.2 + 8.0925567
# Out:
# 11.791003292

# %%
plt.plot(res)

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, 8.0925567 + 0.05344576 * x_test, 'r')
plt.show()
